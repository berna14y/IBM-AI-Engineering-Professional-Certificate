# %%
conda install -c conda-forge jupyterlab
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/bernayilmaz/opt/anaconda3
#
#   added / updated specs:
#     - jupyterlab
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-23.1.0               |   py39h6e9494a_0         908 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         912 KB
#
# The following NEW packages will be INSTALLED:
#
#   python_abi         conda-forge/osx-64::python_abi-3.9-2_cp39
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-23.1.0-py39hecd8cb5_0 --> conda-forge::conda-23.1.0-py39h6e9494a_0
#
#
#
# Downloading and Extracting Packages
# python_abi-3.9       | 4 KB      |                                       |   0%
# conda-23.1.0         | 908 KB    |                                       |   0%
# python_abi-3.9       | 4 KB      | ##################################### | 100%
# conda-23.1.0         | 908 KB    | #############                         |  35%
# conda-23.1.0         | 908 KB    | #############################3        |  79%
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda -c install anaconda ipython
# Out:
# usage: conda [-h] [-V] command ...
# conda: error: unrecognized arguments: -c
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install tensorflow
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                                   /failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - alabaster -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - anaconda==2022.10 -> python[version='3.10.4|3.7.13|3.9.13|3.8.13',build='hdfd78df_1|hdfd78df_0|hdfd78df_0|hdfd78df_0']
#   - appdirs -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - argon2-cffi -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - argon2-cffi-bindings -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - astroid -> python[version='>=3.11,<3.12.0a0']
#   - atomicwrites -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - automat -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0']
#   - backcall -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0']
#   - backports -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - backports.functools_lru_cache -> python[version='>=2.7,<2.8.0a0']
#   - bcrypt -> python[version='>=3.11,<3.12.0a0']
#   - bkcharts -> python[version='>=3.7.1,<3.8.0a0']
#   - brotlipy -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - clyent -> python[version='>=3.11,<3.12.0a0']
#   - conda-content-trust -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - conda-verify -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - constantly -> python[version='>=2.7,<2.8.0a0|>=3.10,<3.11.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - cssselect -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - cython -> python[version='>=3.11,<3.12.0a0']
#   - daal4py -> python[version='>=2.7,<2.8.0a0']
#   - defusedxml -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - flake8 -> python[version='>=3.11,<3.12.0a0']
#   - glob2 -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - h5py -> python[version='<3']
#   - heapdict -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0']
#   - hyperlink -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - imagecodecs -> python[version='>=2.7,<2.8.0a0']
#   - importlib_metadata -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0']
#   - ipython_genutils -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - ipywidgets -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - jdcal -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - jinja2 -> python[version='>=3.11,<3.12.0a0']
#   - jmespath -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - joblib -> python[version='>=3.11,<3.12.0a0']
#   - lz4 -> python[version='>=3.11,<3.12.0a0']
#   - networkx -> python[version='>=3.11,<3.12.0a0|>=3.7.1,<3.8.0a0']
#   - numba -> python[version='3.4.*|>=3.11,<3.12.0a0']
#   - olefile -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - pathlib -> python[version='>=2.7,<2.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - pexpect -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.5,<3.6.0a0']
#   - ptyprocess -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - pyasn1 -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - pyasn1-modules -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - pyflakes -> python[version='>=3.11,<3.12.0a0']
#   - pyobjc-core -> python[version='>=2.7,<2.8.0a0|>=3.11,<3.12.0a0|>=3.5,<3.6.0a0']
#   - pyrsistent -> python[version='>=3.5,<3.6.0a0']
#   - python-dateutil -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - qstylizer -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - requests-file -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - ruamel.yaml -> python[version='>=2.7,<2.8.0a0|>=3.11,<3.12.0a0|>=3.5,<3.6.0a0']
#   - scikit-learn-intelex -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - send2trash -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0']
#   - service_identity -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - sniffio -> python[version='>=3,<3.7']
#   - sortedcollections -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - soupsieve -> python[version='>=3.5,<3.6.0a0']
#   - sympy -> python[version='>=3.11,<3.12.0a0']
#   - tblib -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - tenacity -> python[version='>=3.5,<3.6.0a0']
#   - text-unidecode -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - tomlkit -> python[version='>=3.5,<3.6.0a0']
#   - tornado -> python[version='>=3.11,<3.12.0a0']
#   - w3lib -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - watchdog -> python[version='>=3.5,<3.6.0a0']
#   - wcwidth -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - websocket-client -> python[version='>=3.5,<3.6.0a0']
#   - wheel -> python[version='>=3.11,<3.12.0a0']
#   - wurlitzer -> python[version='<3.4']
#   - xlrd -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - yapf -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - zope.interface -> python[version='>=3.11,<3.12.0a0']
#
# Your python: python=3.9
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package libcxx conflicts for:
# matplotlib-base -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# holoviews -> matplotlib-base[version='>=3'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyqt -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# matplotlib-inline -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyobjc-core -> libffi[version='>=3.4,<3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# tifffile -> imagecodecs[version='>=2021.4.28'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pytz -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# jdcal -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# conda-package-handling -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# snowballstemmer -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# brotlipy -> python[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# qtpy -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pysocks -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# param -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# munkres -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mkl_random -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# tornado -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# qtwebkit -> glib -> libcxx[version='>=10.0.0|>=14.0.6|>=4.0.1']
# filelock -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pytest -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# toolz -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mkl -> libcxx[version='>=12.0.0']
# notebook -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# llvmlite -> libllvm11[version='>=11.1.0,<11.2.0a0'] -> libcxx[version='>=14.0.6|>=4.0.0']
# tblib -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyopenssl -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# jupyter_server -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# datashape -> numpy[version='>=1.7'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ld64 -> libcxx==4.0.1[build='h579ed51_0|hcfea43d_1']
# binaryornot -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# imagecodecs -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6']
# debugpy -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=14.0.6|>=4.0.1']
# incremental -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# nbformat -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyerfa -> numpy[version='>=1.20.2,<2.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ply -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# prompt_toolkit -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# partd -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mpmath -> python[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# bottleneck -> numpy[version='>=1.16.6,<2.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cctools_osx-64 -> libllvm14[version='>=14.0.6,<14.1.0a0'] -> libcxx[version='>=10.a0|>=12|>=14']
# automat -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# nbconvert -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# icu -> libcxx[version='>=10.0.0|>=4.0.1']
# libnghttp2 -> libcxx[version='>=10.0.0|>=12.0.0']
# matplotlib -> libcxx[version='>=4.0.1']
# charls -> libcxx[version='>=10.0.0']
# libspatialindex -> libcxx[version='>=10.0.0|>=4.0.1']
# sphinxcontrib-qthelp -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# python-lsp-server -> ujson[version='>=3.0.0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# sniffio -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# rtree -> libspatialindex[version='>=1.8.5'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# jinja2 -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyparsing -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pycparser -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# wurlitzer -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# zstd -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# sphinxcontrib-serializinghtml -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cycler -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libllvm11 -> libcxx[version='>=10.0.0|>=4.0.0']
# cython -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libzopfli -> libcxx[version='>=10.0.0']
# bkcharts -> numpy[version='>=1.7.1'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# qt -> qt-main[version='>=5.15,<6'] -> libcxx[version='>=12.0.0']
# pyobjc-framework-cocoa -> libffi[version='>=3.4,<4.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libpq -> krb5[version='>=1.17.1,<1.18.0a0'] -> libcxx[version='>=4.0.1']
# requests -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# zfp -> libcxx[version='>=10.0.0|>=12.0.0']
# ncurses -> libcxx[version='>=4.0.1']
# three-merge -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# numexpr -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# py -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libwebp -> libtiff[version='>=4.1.0,<5.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# iniconfig -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# webencodings -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# entrypoints -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# conda-verify -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# tensorflow -> python=3.8 -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# distributed -> msgpack-python[version='>=0.6.0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1|>=14.0.6']
# xarray -> numpy[version='>=1.20'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ujson -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# tenacity -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# zeromq -> libcxx[version='>=10.0.0|>=4.0.1']
# brotli -> libcxx[version='>=10.0.0|>=4.0.1']
# ujson -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=14.0.6']
# pyqtwebengine -> libcxx[version='>=12.0.0']
# nose -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# jsonschema -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# anaconda==2022.10 -> blosc==1.21.0=h8346a28_1 -> libcxx[version='>=*|>=10.0.0|>=12.0.0|>=4.0.1|>=4.0.0|>=10.a0|>=12']
# gmpy2 -> gmp[version='>=6.1.2'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1|>=14.0.6']
# pyobjc-framework-fsevents -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mypy_extensions -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pip -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# glib -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# zope -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libtiff -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cctools -> libllvm12[version='>=12.0.0,<12.1.0a0'] -> libcxx[version='>=10.0.0|>=10.a0|>=4.0.1']
# backports.tempfile -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# unidecode -> python[version='2.7|>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cssselect -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cookiecutter -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# zstd -> lz4-c[version='>=1.9.3,<1.10.0a0'] -> libcxx[version='>=14.0.6']
# liblief -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# widgetsnbextension -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# colorcet -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pydispatcher -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# sphinxcontrib-htmlhelp -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# gstreamer -> gettext -> libcxx[version='>=10.0.0|>=14.0.6|>=12.0.0|>=4.0.1']
# python-dateutil -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# sip -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=14.0.6']
# openpyxl -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# debugpy -> libcxx[version='>=10.0.0|>=12.0.0']
# pyhamcrest -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libffi -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# _ipyw_jlab_nb_ext_conf -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ruamel.yaml.clib -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# python=3.9 -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6']
# lerc -> libcxx[version='>=10.0.0|>=12.0.0']
# astroid -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# websocket-client -> python[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# libcurl -> libnghttp2[version='>=1.46.0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# typing-extensions -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyodbc -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# matplotlib -> matplotlib-base[version='>=3.7.0,<3.7.1.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6']
# beautifulsoup4 -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ld64_osx-64 -> libcxx
# readline -> ncurses[version='>=6.2,<7.0a0'] -> libcxx[version='>=4.0.1']
# watchdog -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# send2trash -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyasn1-modules -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# jupyter -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# sphinxcontrib-devhelp -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# prompt-toolkit -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# brunsli -> libcxx[version='>=10.0.0']
# zope.interface -> python[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# argon2-cffi-bindings -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# tomli -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyyaml -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# bleach -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# openjpeg -> libcxx[version='>=10.0.0|>=4.0.1']
# ipykernel -> debugpy[version='>=1.0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1|>=14.0.6']
# imagecodecs -> openjpeg[version='>=2.3.0,<3.0a0'] -> libcxx[version='>=4.0.1']
# patsy -> numpy[version='>=1.4.0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# text-unidecode -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pickleshare -> python[version='>=3'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# scikit-learn -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# pygments -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mccabe -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# openjpeg -> libtiff[version='>=4.1.0,<5.0a0'] -> libcxx[version='>=12.0.0|>=14.0.6']
# parso -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# qt-main -> glib[version='>=2.69.1,<3.0a0'] -> libcxx[version='>=10.0.0|>=14.0.6|>=4.0.1']
# scikit-learn-intelex -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# sortedcontainers -> python[version='>=2.7'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# jupyterlab_server -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# parsel -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# dataclasses -> python[version='>=3.7'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# joblib -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# krb5 -> libcxx[version='>=4.0.1']
# libedit -> ncurses[version='>=6.2,<7.0a0'] -> libcxx[version='>=4.0.1']
# mkl_fft -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# qtawesome -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyrsistent -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# tapi -> libcxx[version='>=*|>=10.0.0.a0|>=12.0.0.a0']
# numpy-base -> libcxx[version='>=12.0.0|>=14.0.6']
# tldextract -> python[version='>=3.7'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ruamel_yaml -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# typing_extensions -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# conda-pack -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# python-snappy -> libcxx[version='>=10.0.0|>=14.0.6|>=12.0.0|>=4.0.1']
# cffi -> libffi[version='>=3.4,<3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# panel -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# lxml -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pexpect -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# fsspec -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# spyder -> pyqt[version='>=5.6,<5.16'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1|>=14.0.6']
# statsmodels -> numpy[version='>=1.16.6,<2.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cryptography -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libxslt -> icu[version='>=58.2,<59.0a0'] -> libcxx[version='>=4.0.1']
# importlib-metadata -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# wrapt -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# scikit-image -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# bitarray -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# imageio -> numpy -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cctools_osx-64 -> libcxx
# botocore -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# matplotlib-base -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pkginfo -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyviz_comms -> python[version='>=2.7'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# jupyterlab -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libclang -> libllvm14[version='>=14.0.6,<14.1.0a0'] -> libcxx[version='>=10.a0|>=12|>=14|>=4.0.1']
# jupyter_console -> pyzmq[version='>=17'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1|>=14.0.6']
# pylint -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# spyder-kernels -> pyzmq[version='>=22.1.0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# nest-asyncio -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# conda-token -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pywavelets -> numpy[version='>=1.21.5,<2.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# gettext -> libffi[version='>=3.2.1,<3.3a0'] -> libcxx[version='>=4.0.1']
# hyperlink -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# numba -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1|>=7.0.0']
# dal -> libcxx[version='>=12.0.0']
# ruamel.yaml -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# llvmlite -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# bokeh -> contourpy[version='>=1'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# markdown -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# dask -> numpy[version='>=1.18'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# scipy -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# itemloaders -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# arrow -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# sympy -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# s3transfer -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# appscript -> python[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# black -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# astropy -> numpy[version='>=1.16.6,<2.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# poyo -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# diff-match-patch -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ipython -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# defusedxml -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyobjc-framework-coreservices -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# urllib3 -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cytoolz -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# dal -> tbb=2021 -> libcxx[version='>=10.0.0|>=14.0.6']
# pyflakes -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# sqlite -> ncurses[version='>=6.2,<7.0a0'] -> libcxx[version='>=4.0.1']
# constantly -> python[version='>=3.5,<3.6.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# python-libarchive-c -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# queuelib -> python[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# jinja2-time -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libclang -> libcxx[version='>=10.0.0|>=12.0.0']
# python-lsp-jsonrpc -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# py-lief -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# tapi -> ncurses[version='>=6.2,<7.0a0'] -> libcxx[version='>=4.0.1']
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# zict -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# importlib_metadata -> python[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# tbb4py -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# argon2-cffi -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# conda-repo-cli -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# anaconda-project -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cython -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# whatthepatch -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# olefile -> python[version='>=3.5,<3.6.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# locket -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# nbclassic -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyzmq -> libcxx[version='>=12.0.0|>=4.0.1']
# python=3.9 -> libffi[version='>=3.3,<3.4.0a0'] -> libcxx[version='>=4.0.1']
# numexpr -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# msgpack-python -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=14.0.6']
# yapf -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mkl_random -> numpy[version='>=1.21,<2.0a0'] -> libcxx[version='>=14.0.6']
# mistune -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyasn1 -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# fonttools -> brotli[version='>=1.0.1'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# pyqt5-sip -> libcxx[version='>=12.0.0']
# mpfr -> gmp[version='>=6.1.2'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# tbb -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# dask-core -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# idna -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libllvm14 -> libcxx[version='>=12|>=14']
# regex -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# chardet -> python[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# pytables -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# keyring -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# anaconda-client -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# soupsieve -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# wheel -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# textdistance -> python[version='>=2.7'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# python-slugify -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# future -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# heapdict -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# conda[version='>=23.1.0'] -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# lazy-object-proxy -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# intervaltree -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# numba -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# pycurl -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# sqlalchemy -> greenlet!=0.4.17 -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# python.app -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# twisted -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# packaging -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libaec -> libcxx[version='>=10.0.0']
# gmp -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# ld64 -> libllvm12[version='>=12.0.0,<12.1.0a0'] -> libcxx[version='>=*|>=10.0.0|>=10.0.0.a0|>=10.a0|>=12.0.0.a0|>=4.0.1']
# terminado -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# py-lief -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# dill -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mkl-service -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# numpy -> libcxx[version='>=12.0.0|>=14.0.6']
# babel -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# anaconda-navigator==2.4.0 -> pillow[version='>=8.2'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# toml -> python[version='>=2.7'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# msgpack-python -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# h5py -> hdf5[version='>=1.10.6,<1.10.7.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cloudpickle -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# flask -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pep8 -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# markupsafe -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pillow -> libtiff[version='>=4.2.0,<5.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1']
# sphinxcontrib-jsmath -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# multipledispatch -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyqt5-sip -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6']
# python-snappy -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# xlwings -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# blosc -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ptyprocess -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# platformdirs -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ipython_genutils -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ipywidgets -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# cctools -> libcxx==4.0.1[build='h579ed51_0|hcfea43d_1']
# libllvm14 -> libffi[version='>=3.4,<3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# gst-plugins-base -> libcxx[version='>=10.0.0|>=14.0.6|>=4.0.1']
# itemadapter -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# colorama -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# python-fastjsonschema -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# qt-main -> libcxx[version='>=12.0.0']
# alabaster -> python[version='>=2.7,<2.8.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# appdirs -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# curl -> krb5[version='>=1.17.1,<1.18.0a0'] -> libcxx[version='>=4.0.1']
# tbb4py -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# nbclient -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# requests-file -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyls-spyder -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# conda-build -> cctools -> libcxx[version='4.0.1|>=14.0.6|>=12.0.0|>=10.0.0|>=4.0.1',build='h579ed51_0|hcfea43d_1']
# pydocstyle -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# itsdangerous -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyjwt -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# w3lib -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# ld64_osx-64 -> libllvm14[version='>=14.0.6,<14.1.0a0'] -> libcxx[version='>=*|>=12|>=14|>=10.a0']
# backports.weakref -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pycosat -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# bcrypt -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# gst-plugins-base -> glib[version='>=2.69.1,<3.0a0'] -> libcxx[version='>=12.0.0']
# sphinx -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pathlib -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# datashader -> numba[version='>=0.51'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1|>=7.0.0']
# scrapy -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# sip -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# pytables -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# qstylizer -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# docutils -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# prometheus_client -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# numpy -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1']
# et_xmlfile -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# isort -> python[version='>=3.6.1,<4.0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=14.0.6']
# nss -> libcxx[version='>=12.0.0|>=4.0.1']
# backports.functools_lru_cache -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# setuptools -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# threadpoolctl -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# seaborn -> matplotlib-base[version='>=3.1,!=3.6.1'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# backports -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# attrs -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# click -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# backcall -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# qt-webengine -> libcxx[version='>=12.0.0']
# jupyterlab_widgets -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# plotly -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# hdf5 -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# mpich -> libcxx[version='>=4.0.1']
# clyent -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# anaconda==2022.10 -> libcxx==14.0.6=h9765a3e_0
# gettext -> libcxx[version='>=10.0.0']
# rope -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# nspr -> libcxx[version='>=12.0.0|>=4.0.1']
# zipp -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# intel-openmp -> libcxx[version='>=12.0.0']
# libllvm12 -> libcxx[version='>=10.a0']
# navigator-updater -> pyqt[version='>=5.6,<6.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1|>=14.0.6']
# pandas -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# networkx -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# intake -> msgpack-python -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1|>=14.0.6']
# tinycss -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# scikit-image -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# atomicwrites -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# greenlet -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=4.0.1']
# mkl_fft -> numpy[version='>=1.21,<2.0a0'] -> libcxx[version='>=14.0.6']
# kiwisolver -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# xlsxwriter -> python[version='>=3.4'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# python-lsp-black -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# scikit-learn -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# autopep8 -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# lz4 -> lz4-c[version='>=1.9.3,<1.10.0a0'] -> libcxx[version='>=10.0.0|>=14.0.6|>=12.0.0|>=4.0.1']
# nltk -> python[version='>=3.7'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyqtwebengine -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=14.0.6|>=4.0.1']
# json5 -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pandas -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# wcwidth -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# smart_open -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# tqdm -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# glob2 -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pcre -> libcxx[version='>=10.0.0|>=4.0.1']
# jmespath -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# certifi -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# snappy -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# pluggy -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# greenlet -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6']
# jedi -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# hvplot -> numpy[version='>=1.15'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# traitlets -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# charset-normalizer -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# boto3 -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# psutil -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# lz4-c -> libcxx[version='>=10.0.0|>=14.0.6|>=12.0.0|>=4.0.1']
# protego -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# inflection -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mock -> python[version='>=3.6'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# qdarkstyle -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# imagesize -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# numpydoc -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# scipy -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# jupyter_core -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# tomlkit -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# sortedcollections -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# qtwebkit -> libcxx[version='>=12.0.0']
# jellyfish -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# flake8 -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyct -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libxml2 -> icu[version='>=58.2,<59.0a0'] -> libcxx[version='>=4.0.1']
# jupyter_client -> pyzmq[version='>=23.0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# qtconsole -> pyqt -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1|>=14.0.6']
# appnope -> python[version='>=3.6,<3.7.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1|>=14.0.6|>=12.0.0']
# xlrd -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyodbc -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=14.0.6']
# jupyterlab_pygments -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pathspec -> python[version='>=3.7,<3.8.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# libarchive -> lz4-c[version='>=1.9.4,<1.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# numpy-base -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=4.0.1']
# service_identity -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# six -> python -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# mpc -> gmp[version='>=6.1.2'] -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1']
# daal4py -> dal==2021.6.0=haf03e11_929 -> libcxx[version='>=10.0.0|>=12.0.0|>=4.0.1|>=14.0.6']
# tabulate -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pyzmq -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=14.0.6']
# kiwisolver -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# anyio -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# gensim -> python[version='>=3.6,<3.7.0a0'] -> libcxx
# pycodestyle -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# testpath -> python[version='>=3.9,<3.10.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# decorator -> python[version='>=3.5'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# gensim -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# pillow -> libcxx[version='>=12.0.0|>=14.0.6']
# applaunchservices -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
# qt -> libcxx[version='>=4.0.1']
# conda-content-trust -> python[version='>=3.8,<3.9.0a0'] -> libcxx[version='>=10.0.0|>=12.0.0|>=14.0.6|>=4.0.1']
#
# Package jupyter_core conflicts for:
# notebook -> jupyter_client[version='>=5.3.4'] -> jupyter_core[version='>=4.7|>=4.9.2']
# jupyter_server -> jupyter_core[version='>=4.4.0|>=4.6.0|>=4.7.0']
# holoviews -> notebook -> jupyter_core[version='>=4.4.0|>=4.6.0|>=4.6.1']
# nbconvert -> jupyter_core[version='>=4.7']
# plotly -> nbformat[version='>=4.2'] -> jupyter_core
# ipywidgets -> nbformat[version='>=4.2.0'] -> jupyter_core
# jupyterlab -> jupyter_core
# jupyter_console -> jupyter_client[version='>=7.0.0'] -> jupyter_core[version='>=4.6.0|>=4.9.2']
# notebook -> jupyter_core[version='>=4.4.0|>=4.6.0|>=4.6.1']
# nbclassic -> jupyter_client[version='>=6.1.1'] -> jupyter_core[version='>=4.4.0|>=4.6.0|>=4.9.2|>=4.7.0|>=4.7']
# spyder-kernels -> jupyter_client[version='>=7.4.9,<8.0.0'] -> jupyter_core[version='>=4.6.0|>=4.9.2']
# qtconsole -> jupyter_core
# jupyter -> jupyter_console -> jupyter_core[version='>=4.12,!=5.0.*|>=4.7|>=4.6.1|>=4.6.0|>=4.4.0']
# widgetsnbextension -> notebook[version='>=4.4.1'] -> jupyter_core[version='>=4.4.0|>=4.6.0|>=4.6.1']
# ipykernel -> jupyter_client[version='>=6.1.12'] -> jupyter_core[version='>=4.6.0|>=4.9.2']
# anaconda==2022.10 -> jupyter_client==7.3.4=py39hecd8cb5_0 -> jupyter_core[version='>=4.6.1|>=4.7.0|>=4.9.2']
# conda-repo-cli -> nbformat[version='>=5.4.0'] -> jupyter_core
# nbclassic -> jupyter_core[version='>=4.6.1']
# anaconda==2022.10 -> jupyter_core==4.11.1[build='py310hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0|py38hecd8cb5_0']
# jupyter_client -> jupyter_core[version='>=4.6.0|>=4.9.2']
# spyder -> nbconvert[version='>=4.0'] -> jupyter_core[version='>=4.7']
# nbconvert -> jupyter_client[version='>=4.2'] -> jupyter_core[version='>=4.6.0|>=4.9.2']
# anaconda-client -> nbformat[version='>=4.4.0'] -> jupyter_core
# nbformat -> jupyter_core
# qtconsole -> jupyter_client[version='>=4.1'] -> jupyter_core[version='>=4.6.0|>=4.9.2']
# _ipyw_jlab_nb_ext_conf -> jupyterlab -> jupyter_core
# jupyterlab_server -> jupyter_server[version='>=1.21,<3'] -> jupyter_core[version='>=4.4.0|>=4.6.0|>=4.7.0|>=4.6.1']
# jupyter_console -> jupyter_core[version='>=4.12,!=5.0.*']
# jupyterlab -> jupyter_server[version='>=1.16,<3'] -> jupyter_core[version='>=4.4.0|>=4.6.0|>=4.6.1|>=4.7.0']
# jupyter_server -> jupyter_client[version='>=6.1.12'] -> jupyter_core[version='>=4.7|>=4.9.2']
# nbclient -> jupyter_client[version='>=6.1.5'] -> jupyter_core[version='>=4.6.0|>=4.9.2']
#
# Package python-dateutil conflicts for:
# ipykernel -> jupyter_client[version='>=6.1.12'] -> python-dateutil[version='>=2.1|>=2.8.2']
# conda-repo-cli -> anaconda-client[version='>=1.7.2'] -> python-dateutil
# botocore -> python-dateutil[version='>=2.1,<2.7.0|>=2.1,<2.8.1|>=2.1,<3.0.0']
# matplotlib-base -> python-dateutil[version='>=2.1|>=2.7']
# nbclassic -> jupyter_client[version='>=6.1.1'] -> python-dateutil[version='>=2.1|>=2.8.2']
# pandas -> python-dateutil[version='>=2.5.*|>=2.6.1|>=2.7.3|>=2.8.1']
# anaconda-project -> anaconda-client -> python-dateutil[version='>=2.6.1']
# panel -> bokeh[version='>=2.3,<2.4'] -> python-dateutil[version='>=2.1']
# scikit-image -> matplotlib-base[version='>=2.0.0,!=3.0.0'] -> python-dateutil[version='>=2.1|>=2.7']
# ...
# attrs -> zope.interface
#
# Package jupyter_console conflicts for:
# holoviews -> jupyter -> jupyter_console
# jupyter -> jupyter_console
# anaconda==2022.10 -> jupyter_console==6.4.3=pyhd3eb1b0_0
# anaconda==2022.10 -> jupyter==1.0.0=py39hecd8cb5_8 -> jupyter_console
#
# Package applaunchservices conflicts for:
# anaconda==2022.10 -> applaunchservices==0.3.0[build='py310hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0|py38hecd8cb5_0']
# spyder -> applaunchservices[version='>=0.1.7|>=0.3.0']
# anaconda==2022.10 -> spyder==5.3.3=py39hecd8cb5_0 -> applaunchservices[version='>=0.3.0']
#
# Package statsmodels conflicts for:
# anaconda==2022.10 -> statsmodels==0.13.2[build='py37hca72f7f_0|py39hca72f7f_0|py310hca72f7f_0|py38hca72f7f_0']
# seaborn -> statsmodels[version='>=0.5.0']
#
# Package pexpect conflicts for:
# jupyter_console -> pexpect
# jupyterlab -> ipython -> pexpect[version='>4.3']
# anaconda==2022.10 -> ipython==7.31.1=py39hecd8cb5_1 -> pexpect[version='>4.3|>=4.4.0']
# ipykernel -> ipython[version='>=7.23.1'] -> pexpect[version='>4.3']
# jupyter_console -> ipython -> pexpect[version='>4.3']
# holoviews -> ipython[version='>=5.4.0'] -> pexpect[version='>4.3']
# spyder-kernels -> ipython[version='>=7.31.1,<9.0.0'] -> pexpect[version='>4.3']
# spyder -> pexpect[version='>=4.4.0']
# ipywidgets -> ipython[version='>=4.0.0'] -> pexpect[version='>4.3']
# spyder -> ipython[version='>=7.31.1,<9.0.0'] -> pexpect[version='>4.3']
# ipython -> pexpect[version='>4.3']
# anaconda==2022.10 -> pexpect==4.8.0=pyhd3eb1b0_3
# jupyter -> jupyter_console -> pexpect
#
# Package argon2-cffi-bindings conflicts for:
# anaconda==2022.10 -> argon2-cffi-bindings==21.2.0[build='py37hca72f7f_0|py39hca72f7f_0|py310hca72f7f_0|py38hca72f7f_0']
# notebook -> argon2-cffi -> argon2-cffi-bindings
# nbclassic -> argon2-cffi -> argon2-cffi-bindings
# anaconda==2022.10 -> argon2-cffi==21.3.0=pyhd3eb1b0_0 -> argon2-cffi-bindings
# argon2-cffi -> argon2-cffi-bindings
# jupyter_server -> argon2-cffi -> argon2-cffi-bindings
#
# Package mpich conflicts for:
# anaconda==2022.10 -> mpich==3.3.2[build='hc856adb_0|external_0']
# daal4py -> mpich[version='>=3.3.2,<3.4.0a0']
# anaconda==2022.10 -> daal4py==2021.6.0=py39h01d92e1_1 -> mpich[version='>=3.3.2,<3.4.0a0']
# scikit-learn-intelex -> daal4py=2021.6.0 -> mpich[version='>=3.3.2,<3.4.0a0']
#
# Package diff-match-patch conflicts for:
# anaconda==2022.10 -> diff-match-patch==20200713=pyhd3eb1b0_0
# anaconda==2022.10 -> spyder==5.3.3=py39hecd8cb5_0 -> diff-match-patch[version='>=20181111']
# three-merge -> diff-match-patch
# spyder -> diff-match-patch[version='>=20181111']
#
# Package libunistring conflicts for:
# anaconda==2022.10 -> libidn2==2.3.2=h9ed2024_0 -> libunistring[version='>=0,<1.0a0']
# anaconda==2022.10 -> libunistring==0.9.10=h9ed2024_0
# libidn2 -> libunistring[version='>=0,<1.0a0']
# wget -> libidn2[version='>=2,<3.0a0'] -> libunistring[version='>=0,<1.0a0']
#
# Package gensim conflicts for:
# anaconda==2022.10 -> gensim==4.1.2[build='py37he9d5cce_0|py39he9d5cce_0|py310he9d5cce_0|py38he9d5cce_0']
# nltk -> gensim
#
# Package curl conflicts for:
# anaconda==2022.10 -> curl==7.84.0=hca72f7f_0
# pycurl -> curl[version='7.55.*|>=7.55.1,<8.0a0']
#
# Package mpmath conflicts for:
# anaconda==2022.10 -> sympy==1.10.1=py39hecd8cb5_0 -> mpmath[version='>=0.19']
# sympy -> mpmath[version='>=0.19']
# anaconda==2022.10 -> mpmath==1.2.1[build='py310hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0|py38hecd8cb5_0']
#
# Package pandocfilters conflicts for:
# spyder -> nbconvert[version='>=4.0'] -> pandocfilters[version='>=1.4.1']
# anaconda==2022.10 -> pandocfilters==1.5.0=pyhd3eb1b0_0
# jupyter_server -> nbconvert[version='>=6.4.4'] -> pandocfilters[version='>=1.4.1']
# jupyter -> nbconvert -> pandocfilters[version='>=1.4.1']
# notebook -> nbconvert[version='>=5'] -> pandocfilters[version='>=1.4.1']
# nbconvert -> pandocfilters[version='>=1.4.1']
# nbclassic -> nbconvert[version='>=5'] -> pandocfilters[version='>=1.4.1']
# anaconda==2022.10 -> nbconvert==6.4.4=py39hecd8cb5_0 -> pandocfilters[version='>=1.4.1']
#
# Package python-lsp-black conflicts for:
# anaconda==2022.10 -> python-lsp-black==1.2.1[build='py310hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0|py38hecd8cb5_0']
# anaconda==2022.10 -> spyder==5.3.3=py39hecd8cb5_0 -> python-lsp-black[version='>=1.2.0']
# spyder -> python-lsp-black[version='>=1.0.0|>=1.2.0']
#
# Package imageio conflicts for:
# anaconda==2022.10 -> scikit-image==0.19.2=py39hae1ba45_0 -> imageio[version='>=2.4.1']
# scikit-image -> imageio[version='>=2.1.0|>=2.16.2|>=2.4.1|>=2.3.0']
# datashader -> scikit-image -> imageio[version='>=2.1.0|>=2.16.2|>=2.4.1|>=2.3.0']
# anaconda==2022.10 -> imageio==2.19.3[build='py310hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0|py38hecd8cb5_0']
#
# Package tomlkit conflicts for:
# anaconda==2022.10 -> pylint==2.14.5=py39hecd8cb5_0 -> tomlkit[version='>=0.10.1']
# spyder -> pylint[version='>=2.5.0,<3.0'] -> tomlkit[version='>=0.10.1']
# anaconda==2022.10 -> tomlkit==0.11.1[build='py310hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0|py38hecd8cb5_0']
# pylint -> tomlkit[version='>=0.10.1']
# python-lsp-server -> pylint[version='>=2.5.0,<3.0.0'] -> tomlkit[version='>=0.10.1']
#
# Package pydispatcher conflicts for:
# scrapy -> pydispatcher[version='>=2.0.5']
# anaconda==2022.10 -> pydispatcher==2.0.5[build='py37hecd8cb5_2|py39hecd8cb5_2|py310hecd8cb5_2|py38hecd8cb5_2']
# anaconda==2022.10 -> scrapy==2.6.2=py39hecd8cb5_0 -> pydispatcher[version='>=2.0.5']
#
# Package cookiecutter conflicts for:
# anaconda==2022.10 -> cookiecutter==1.7.3=pyhd3eb1b0_0
# anaconda==2022.10 -> spyder==5.3.3=py39hecd8cb5_0 -> cookiecutter[version='>=1.6.0']
# spyder -> cookiecutter[version='>=1.6.0']
#
# Package boto3 conflicts for:
# gensim -> smart_open[version='>=1.8.1'] -> boto3
# anaconda==2022.10 -> boto3==1.24.28[build='py310hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0|py38hecd8cb5_0']
# smart_open -> boto3
#
# Package immutables conflicts for:
# distributed -> contextvars -> immutables[version='>=0.9']
# sniffio -> contextvars[version='>=2.1'] -> immutables[version='>=0.9']
#
# Package conda-env conflicts for:
# navigator-updater -> conda -> conda-env[version='>=2.6']
# conda-build -> conda[version='>=4.5'] -> conda-env[version='>=2.6']
# anaconda-navigator==2.4.0 -> conda!=22.11.* -> conda-env[version='>=2.6']
# conda-token -> conda[version='>=4.3'] -> conda-env[version='>=2.6']
#
# Package tblib conflicts for:
# dask -> distributed=2022.7.0 -> tblib[version='>=1.6.0']
# anaconda==2022.10 -> tblib==1.7.0=pyhd3eb1b0_0
# anaconda==2022.10 -> distributed==2022.7.0=py39hecd8cb5_0 -> tblib[version='>=1.6.0']
# distributed -> tblib[version='>=1.6.0']
#
# Package soupsieve conflicts for:
# anaconda==2022.10 -> beautifulsoup4==4.11.1=py39hecd8cb5_0 -> soupsieve[version='>=1.2']
# nbconvert -> beautifulsoup4 -> soupsieve[version='>=1.2']
# beautifulsoup4 -> soupsieve[version='>=1.2']
# anaconda==2022.10 -> soupsieve==2.3.1=pyhd3eb1b0_0
# conda-build -> beautifulsoup4 -> soupsieve[version='>=1.2']
#
# Package conda conflicts for:
# conda-token -> conda[version='>=4.3']
# anaconda-navigator==2.4.0 -> conda-token -> conda[version='>=4.3']
# anaconda==2022.10 -> conda-token==0.4.0=pyhd3eb1b0_0 -> conda[version='>=4.3']
# navigator-updater -> conda
# conda-build -> conda[version='<4.13.0|>=4.13|>=4.5|>=4.5,<4.13.0|>=4.3,<4.13.0']
# anaconda-navigator==2.4.0 -> conda!=22.11.*
#
# Package funcsigs conflicts for:
# astropy -> pytest[version='<4'] -> funcsigs[version='>=1.0']
# mock -> funcsigs
# numba -> funcsigs
# datashader -> numba[version='>=0.37.0,!=0.49.*,!=0.50.*'] -> funcsigs
# pytest -> funcsigs[version='>=1.0']
# pytables -> mock -> funcsigs
#
# Package itemloaders conflicts for:
# anaconda==2022.10 -> scrapy==2.6.2=py39hecd8cb5_0 -> itemloaders[version='>=1.0.1']
# scrapy -> itemloaders[version='>=1.0.1']
# anaconda==2022.10 -> itemloaders==1.0.4=pyhd3eb1b0_1
#
# Package pydocstyle conflicts for:
# pyls-spyder -> python-lsp-server[version='>=1.0.1'] -> pydocstyle[version='>=2.0.0|>=6.3.0,<6.4.0']
# spyder -> python-lsp-server[version='>=1.7.1,<1.8.0'] -> pydocstyle[version='>=2.0.0|>=6.3.0,<6.4.0']
# anaconda==2022.10 -> python-lsp-server==1.5.0=py39hecd8cb5_0 -> pydocstyle[version='>=2.0.0']
# anaconda==2022.10 -> pydocstyle==6.1.1=pyhd3eb1b0_0
# python-lsp-black -> python-lsp-server[version='>=1.4.0'] -> pydocstyle[version='>=2.0.0|>=6.3.0,<6.4.0']
# python-lsp-server -> pydocstyle[version='>=2.0.0|>=6.3.0,<6.4.0']
#
# Package backports.tempfile conflicts for:
# conda-build -> conda-verify -> backports.tempfile
# anaconda==2022.10 -> backports.tempfile==1.0=pyhd3eb1b0_1
# conda-verify -> backports.tempfile
#
# Package ripgrep conflicts for:
# conda-build -> ripgrep
# anaconda==2022.10 -> ripgrep==13.0.0=hc2228c6_0
#
# Package scikit-learn conflicts for:
# nltk -> scikit-learn
# anaconda==2022.10 -> scikit-learn==1.0.2[build='py310hc081a56_0|py37hae1ba45_1|py39hae1ba45_1|py38hae1ba45_1']
# anaconda==2022.10 -> scikit-learn-intelex==2021.6.0=py39hecd8cb5_0 -> scikit-learn[version='<1.1']
# scikit-learn-intelex -> scikit-learn[version='<1.1|>=0.22|>=0.21']
#
# Package mpc conflicts for:
# sympy -> gmpy2[version='>=2.0.8'] -> mpc
# anaconda==2022.10 -> gmpy2==2.1.2=py39hd5de756_0 -> mpc
# anaconda==2022.10 -> mpc==1.1.0=h6ef4df4_1
# gmpy2 -> mpc
#
# Package conda-token conflicts for:
# anaconda-navigator==2.4.0 -> conda-token
# anaconda==2022.10 -> conda-token==0.4.0=pyhd3eb1b0_0
#
# Package pytest conflicts for:
# anaconda==2022.10 -> pytest==7.1.2[build='py310hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0|py38hecd8cb5_0']
# astropy -> pytest-astropy -> pytest[version='>=3.1.0|>=3.1|>=4.6']
# astropy -> pytest[version='<3.7|<4']
# parsel -> pytest-runner -> pytest
#
# Package pyobjc-framework-coreservices conflicts for:
# anaconda==2022.10 -> pyobjc-framework-coreservices==8.5[build='py37hca72f7f_0|py39hca72f7f_0|py310hca72f7f_0|py38hca72f7f_0']
# spyder -> applaunchservices[version='>=0.3.0'] -> pyobjc-framework-coreservices
# applaunchservices -> pyobjc-framework-coreservices
# anaconda==2022.10 -> applaunchservices==0.3.0=py39hecd8cb5_0 -> pyobjc-framework-coreservices
#
# Package inflection conflicts for:
# spyder -> qstylizer[version='>=0.2.2'] -> inflection[version='>0.3.0,<1.0']
# qstylizer -> inflection[version='>0.3.0,<1.0']
# anaconda==2022.10 -> inflection==0.5.1[build='py310hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0|py38hecd8cb5_0']
# anaconda==2022.10 -> qstylizer==0.1.10=pyhd3eb1b0_0 -> inflection[version='>0.3.0,<1.0']
#
# Package selectors2 conflicts for:
# spyder-kernels -> wurlitzer[version='>=1.0.3'] -> selectors2
# wurlitzer -> selectors2
#
# Package datashape conflicts for:
# anaconda==2022.10 -> datashape==0.5.4[build='py310hecd8cb5_1|py39hecd8cb5_1|py37hecd8cb5_1|py38hecd8cb5_1']
# anaconda==2022.10 -> datashader==0.14.1=py39hecd8cb5_0 -> datashape[version='>=0.5.1']
# datashader -> datashape[version='>=0.5.1']
#
# Package anaconda-client conflicts for:
# anaconda==2022.10 -> anaconda-client==1.11.0[build='py310hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0|py38hecd8cb5_0']
# conda-repo-cli -> anaconda-client[version='>=1.7.2']
# anaconda==2022.10 -> anaconda-project==0.11.1=py39hecd8cb5_0 -> anaconda-client
# anaconda-project -> anaconda-client
# anaconda-navigator==2.4.0 -> anaconda-client[version='>=1.6.14']
# anaconda-navigator==2.4.0 -> conda-repo-cli -> anaconda-client[version='>=1.7.2']
#
# Package more-itertools conflicts for:
# importlib-metadata -> zipp[version='>=0.5'] -> more-itertools
# zipp -> jaraco.itertools -> more-itertools[version='>=4.0.0']
# astropy -> pytest[version='<4'] -> more-itertools[version='>=4.0,<6.0|>=4.0|>=4.0.0']
# importlib_metadata -> zipp[version='>=0.5'] -> more-itertools
# zipp -> more-itertools
# pytest -> more-itertools[version='>=4.0,<6.0|>=4.0|>=4.0.0']
#
# Package rope conflicts for:
# python-lsp-black -> python-lsp-server[version='>=1.4.0'] -> rope[version='>=0.10.5|>=1.2.0']
# spyder -> python-lsp-server[version='>=1.7.1,<1.8.0'] -> rope[version='>=1.2.0']
# anaconda==2022.10 -> python-lsp-server==1.5.0=py39hecd8cb5_0 -> rope[version='>=0.10.5']
# python-lsp-server -> rope[version='>=0.10.5|>=1.2.0']
# anaconda==2022.10 -> rope==0.22.0=pyhd3eb1b0_0
# spyder -> rope[version='>=0.10.5|>=0.9.4']
# pyls-spyder -> python-lsp-server[version='>=1.0.1'] -> rope[version='>=0.10.5|>=1.2.0']
#
# Package pbr conflicts for:
# pytables -> mock -> pbr
# mock -> pbr
#
# Package spyder-kernels conflicts for:
# anaconda==2022.10 -> spyder-kernels==2.3.3[build='py310hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0|py38hecd8cb5_0']
# anaconda==2022.10 -> spyder==5.3.3=py39hecd8cb5_0 -> spyder-kernels[version='>=2.3.3,<2.4.0']
# spyder -> spyder-kernels[version='0.*|>=0.1,<1|>=0.4.2,<1|>=0.4.3,<1|>=0.5.0,<1|>=1.10.0,<1.11.0|>=1.10.1,<1.11.0|>=1.10.2,<1.11.0|>=2.0.1,<2.1.0|>=2.0.3,<2.1.0|>=2.0.4,<2.1.0|>=2.1.1,<2.2.0|>=2.2.1,<2.3.0|>=2.3.3,<2.4.0|>=2.4.1,<2.5.0|>=2.4.2,<2.5.0|>=1.9.4,<1.10.0|>=1.9.2,<1.10.0|>=1.9.1,<1.10.0|>=1.9.0,<1.10.0|>=1.8.1,<1.9.0']
#
# Package queuelib conflicts for:
# anaconda==2022.10 -> queuelib==1.5.0[build='py310hecd8cb5_0|py39hecd8cb5_0|py37hecd8cb5_0|py38hecd8cb5_0']
# anaconda==2022.10 -> scrapy==2.6.2=py39hecd8cb5_0 -> queuelib[version='>=1.4.2']
# scrapy -> queuelib[version='>=1.4.2']
#
# Package c-ares conflicts for:
# anaconda==2022.10 -> libnghttp2==1.46.0=ha29bfda_0 -> c-ares[version='>=1.17.1,<2.0a0|>=1.7.5']
# anaconda==2022.10 -> c-ares==1.18.1=hca72f7f_0
# libcurl -> libnghttp2[version='>=1.46.0'] -> c-ares[version='>=1.16.1,<2.0a0|>=1.17.1,<2.0a0|>=1.7.5']
# libnghttp2 -> c-ares[version='>=1.16.1,<2.0a0|>=1.17.1,<2.0a0|>=1.7.5']
#
# Package cctools conflicts for:
# conda-build -> cctools
# anaconda==2022.10 -> cctools==949.0.1=h9abeeb2_25
#
# Package bz2file conflicts for:
# smart_open -> bz2file
# gensim -> smart_open[version='>=1.8.1'] -> bz2file
#
# Package pkginfo conflicts for:
# conda-build -> pkginfo
# anaconda==2022.10 -> pkginfo==1.8.2=pyhd3eb1b0_0
#
# Package rtree conflicts for:
# anaconda==2022.10 -> rtree==0.9.7[build='py310hecd8cb5_1|py39hecd8cb5_1|py37hecd8cb5_1|py38hecd8cb5_1']
# spyder -> rtree[version='>=0.8.3|>=0.9.7']
# anaconda==2022.10 -> spyder==5.3.3=py39hecd8cb5_0 -> rtree[version='>=0.9.7']
#
# Package py-lief conflicts for:
# conda-build -> py-lief
# anaconda==2022.10 -> py-lief==0.11.5[build='py310he9d5cce_1|py39he9d5cce_1|py37he9d5cce_1|py38he9d5cce_1']
#
# Package itsdangerous conflicts for:
# anaconda==2022.10 -> flask==1.1.2=pyhd3eb1b0_0 -> itsdangerous[version='>=0.24']
# flask -> itsdangerous[version='>=0.21|>=0.24|>=0.24,<2.0|>=2.0']
# anaconda==2022.10 -> itsdangerous==2.0.1=pyhd3eb1b0_0
#
# Package python-language-server conflicts for:
# spyder -> pyls-black[version='>=0.4.6'] -> python-language-server[version='>=0.36.2']
# spyder -> python-language-server[version='>=0.31.2,<0.32.0|>=0.31.9,<0.32.0|>=0.34.0,<1.0.0|>=0.36.1,<1.0.0|>=0.36.2,<1.0.0']
#
# Package libllvm9 conflicts for:
# llvmlite -> libllvm9==9.0.1[build=*_1]
# numba -> llvmlite[version='>=0.33.0',build=*_1] -> libllvm9==9.0.1[build=*_1]
#
# Package qtawesome conflicts for:
# spyder -> qtawesome[version='>=0.4.1|>=0.5.7|>=1.0.2|>=1.2.1']
# anaconda==2022.10 -> spyder==5.3.3=py39hecd8cb5_0 -> qtawesome[version='>=1.0.2']
# anaconda==2022.10 -> qtawesome==1.0.3=pyhd3eb1b0_0
#
# Package python-jsonrpc-server conflicts for:
# pyls-spyder -> python-language-server[version='>=0.36.2'] -> python-jsonrpc-server[version='>=0.3.2|>=0.4.0']
# spyder -> python-language-server[version='>=0.36.2,<1.0.0'] -> python-jsonrpc-server[version='>=0.3.2|>=0.4.0']
#
# Package whichcraft conflicts for:
# cookiecutter -> whichcraft[version='>=0.4.0']
# spyder -> cookiecutter[version='>=1.6.0'] -> whichcraft[version='>=0.4.0']
#
# Package conda-pack conflicts for:
# anaconda==2022.10 -> anaconda-project==0.11.1=py39hecd8cb5_0 -> conda-pack
# anaconda-project -> conda-packThe following specifications were found to be incompatible with your system:
#
#   - feature:/osx-64::__osx==10.16=0
#   - feature:|@/osx-64::__osx==10.16=0
#   - holoviews -> matplotlib-base[version='>=3'] -> __osx[version='>=10.11']
#   - matplotlib -> matplotlib-base[version='>=3.7.0,<3.7.1.0a0'] -> __osx[version='>=10.11']
#   - matplotlib-base -> __osx[version='>=10.11']
#   - scikit-image -> matplotlib-base[version='>=2.0.0,!=3.0.0'] -> __osx[version='>=10.11']
#   - seaborn -> matplotlib-base[version='>=3.1,!=3.6.1'] -> __osx[version='>=10.11']
#
# Your installed version is: 10.16
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install keras
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/bernayilmaz/opt/anaconda3
#
#   added / updated specs:
#     - keras
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     keras-2.10.0               |   py39hecd8cb5_0         1.6 MB
#     keras-preprocessing-1.1.2  |     pyhd3eb1b0_0          35 KB
#     ------------------------------------------------------------
#                                            Total:         1.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   keras              pkgs/main/osx-64::keras-2.10.0-py39hecd8cb5_0
#   keras-preprocessi~ pkgs/main/noarch::keras-preprocessing-1.1.2-pyhd3eb1b0_0
#
#
#
# Downloading and Extracting Packages
# keras-2.10.0         | 1.6 MB    |                                       |   0%
# keras-2.10.0         | 1.6 MB    | 3                                     |   1%
# keras-2.10.0         | 1.6 MB    | #######                               |  19%
# keras-preprocessing- | 35 KB     | ##################################### | 100%
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge hdf5=1.10.5
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense

# %%
data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
# check how many data points we have
data.shape
# Out:
# (1030, 9)

# %%
#check the dataset for any missing values

# %%
data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
# split data into predictors and target
predictors = data[:, :-1]
target = data[:, -1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), slice(None, -1, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# /var/folders/_6/f3_p26916s3f9449lll5qn_40000gn/T/ipykernel_8027/4001019037.py in <module>
#       1 # split data into predictors and target
# ----> 2 predictors = data[:, :-1]
#       3 target = data[:, -1]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3634                 #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635                 #  the TypeError.
# -> 3636                 self._check_indexing_error(key)
#    3637                 raise
#    3638
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _check_indexing_error(self, key)
#    5649             # if key is not a scalar, directly raise an error (the code below
#    5650             # would convert to numpy arrays and raise later any way) - GH29926
# -> 5651             raise InvalidIndexError(key)
#    5652
#    5653     @cache_readonly
#
# InvalidIndexError: (slice(None, None, None), slice(None, -1, None))

# %%
# split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=42)

# %%
# One hidden layer of 10 nodes and activation function is RELU
def regression_model()
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(X_train.shape[1],)))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# build model
model=regression_model()

# %%
# fit the model
model.fit(X_train, y_train, epochs=50, verbose=0)

# %%
# evaluate the model
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)

print('Mean Squared Error:', mse)

# %%
mse_values = []

for i in range(50):
    # split data into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=i)

    # define model
    model = regression_model()

    # train model
    model.fit(X_train, y_train, epochs=50, verbose=0)

    # evaluate model
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_values.append(mse)

# report mean and standard deviation of MSE values
print('Mean MSE:', np.mean(mse_values))
print('Standard deviation of MSE:', np.std(mse_values))


# This should give us the mean and standard deviation of the MSE values over 50 runs.
